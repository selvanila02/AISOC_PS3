# %%
# !pip install roboflow
# Out:
# ...
#   Using cached roboflow-1.2.14-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# ...
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached pillow_avif_plugin-1.5.5-cp311-cp311-win_amd64.whl.metadata (2.3 kB)
# ...
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached pi_heif-1.2.1-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# ...
# Using cached roboflow-1.2.14-py3-none-any.whl (93 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.8 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.8 MB 1.1 MB/s eta 0:00:35
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Og9LRv6nVrLB3wDmKbh0")
project = rf.workspace("katir").project("pothole-detection-iokyr")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to pothole-detection-1 in yolov5pytorch:: 100%|██████████| 3348/3348 [00:00<00:00, 6348.80it/s]

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17817, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 17817 (delta 12), reused 6 (delta 6), pack-reused 17796 (from 3)
# Receiving objects: 100% (17817/17817), 17.01 MiB | 17.63 MiB/s, done.
# Resolving deltas: 100% (12143/12143), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 39.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 13.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# ...

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !python train.py \
  --img 640 \
  --batch 16 \
  --epochs 50 \
  --data ../pothole-detection-1/data.yaml \
  --weights yolov5n.pt \
  --cache
# Out:
# Streaming output truncated to the last 5000 lines.
#       17/49      2.37G    0.04203    0.03054          0         71        640:  39% 29/74 [00:07<00:12,  3.67it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       17/49      2.37G    0.04204    0.03026          0         55        640:  41% 30/74 [00:07<00:11,  3.97it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       17/49      2.37G      0.042     0.0301          0         58        640:  42% 31/74 [00:07<00:10,  4.18it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
from google.colab import files
files.download('runs/train/exp5/weights/best.pt')

# %%
# %cd ..

# %%
# %cd yolov5
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /content/yolov5

# %%
# !python detect.py \
  --weights runs/train/exp2/weights/best.pt \
  --source patholes.mp4 \
  --img 640 \
  --conf 0.25

# %%
pip install onnx onnxruntime
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 73.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 105.2 MB/s eta 0:00:00
# ...

# %%
# !python export.py \
  --weights runs/train/exp5/weights/best.pt \
  --include onnx \
  --img 320 \
  --simplify \
  --opset 12
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/exp5/weights/best.pt'], imgsz=[320], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=True, mlmodel=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# YOLOv5 🚀 v7.0-460-g3fb11111 Python-3.12.12 torch-2.9.0+cu128 CPU
#
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients, 4.1 GFLOPs
#
# PyTorch: starting from runs/train/exp5/weights/best.pt with output shape (1, 6300, 6) (3.7 MB)
# requirements: Ultralytics requirement ['onnxscript'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 8 packages in 234ms
# Prepared 2 packages in 53ms
# Installed 2 packages in 8ms
#  + onnx-ir==0.1.16
#  + onnxscript==0.6.2
#
# requirements: AutoUpdate success ✅ 0.7s
# ...

# %%
# !mv runs/train/exp5/weights/best.onnx \
   runs/train/exp5/weights/best_320.onnx

# %%
from google.colab import files
files.download('runs/train/exp5/weights/best_320.onnx')
